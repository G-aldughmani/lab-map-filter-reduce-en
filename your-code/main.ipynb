# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources in the README.md file
# - Happy learning!

# %%
# Import reduce from functools, numpy and pandas
from functools import reduce
import numpy
import pandas

# %% [markdown]
# # Challenge 1 - Mapping
#
# #### We will use the map function to clean up words in a book.
#
# In the following cell, we will read a text file containing the book The Prophet by Khalil Gibran.

# %%
# Run this code:

location = '../data/58585-0.txt'
with open(location, 'r', encoding="utf8") as f:
    prophet = f.read().split(' ')

# %%
len(prophet)
# Out:
# 13637

# %% [markdown]
# #### Let's remove the first 568 words since they contain information about the book but are not part of the book itself.
#
# Do this by removing from `prophet` elements 0 through 567 of the list (you can also do this by keeping elements 568 through the last element).

# %%
# your code here
prophet = prophet[568:]
print(len(prophet))
# Out:
# 13069

# %% [markdown]
# If you look through the words, you will find that many words have a reference attached to them. For example, let's look at words 1 through 10.

# %%
# your code here
print(prophet[0:10])
# Out:
# ['PROPHET\n\n|Almustafa,', 'the{7}', 'chosen', 'and', 'the\nbeloved,', 'who', 'was', 'a', 'dawn', 'unto']

# %% [markdown]
# #### The next step is to create a function that will remove references.
#
# We will do this by splitting the string on the `{` character and keeping only the part before this character. Write your function below.

# %%
def reference(prophet):
    '''
    Input: A string
    Output: The string with references removed
    
    Example:
    Input: 'the{7}'
    Output: 'the'
    '''
    return prophet.split('{')[0]
    # your code here

# %%
# your code here
res=reference(prophet[1])
print(res)
# Out:
# the

# %% [markdown]
# Now that we have our function, use the `map()` function to apply this function to our book, The Prophet. Return the resulting list to a new list called `prophet_reference`.

# %%
# your code here
def reference(line):
    return f"Reference: {line}"

prophet_reference = list(map(reference, prophet))
print(prophet_reference)
# Out:
# ['Reference: PROPHET\n\n|Almustafa,', 'Reference: the{7}', 'Reference: chosen', 'Reference: and', 'Reference: the\nbeloved,', 'Reference: who', 'Reference: was', 'Reference: a', 'Reference: dawn', 'Reference: unto', 'Reference: his', 'Reference: own\nday,', 'Reference: had', 'Reference: waited', 'Reference: twelve', 'Reference: years', 'Reference: in', 'Reference: the', 'Reference: city\nof', 'Reference: Orphalese', 'Reference: for', 'Reference: his', 'Reference: ship', 'Reference: that', 'Reference: was', 'Reference: to\nreturn', 'Reference: and', 'Reference: bear', 'Reference: him', 'Reference: back', 'Reference: to', 'Reference: the', 'Reference: isle', 'Reference: of\nhis', 'Reference: birth.\n\nAnd', 'Reference: in', 'Reference: the', 'Reference: twelfth', 'Reference: year,', 'Reference: on', 'Reference: the', 'Reference: seventh\nday', 'Reference: of', 'Reference: Ielool,', 'Reference: the', 'Reference: month', 'Reference: of', 'Reference: reaping,', 'Reference: he\nclimbed', 'Reference: the', 'Reference: hill', 'Reference: without', 'Reference: the', 'Reference: city', 'Reference: walls\nand', 'Reference: looked', 'Reference: seaward;', 'Reference: and', 'Reference: he', 'Reference: beheld', 'Reference: his\nship', 'Reference: coming', 'Reference: with', 'Reference: the', 'Reference: mist.\n\nThen', 'Reference: the', 'Reference: gates', 'Reference: of', 'Reference: his', 'Reference: heart', 'Reference: were', 'Reference: flung\nopen,', 'Reference: and', 'Reference: his', 'Reference: joy', 'Reference: flew', 'Reference: far', 'Reference: over', 'Reference: the', 'Reference: sea.\nAnd', 'Reference: he', 'Reference: closed', 'Reference: his', 'Reference: eyes', 'Reference: and', 'Reference: prayed', 'Reference: in', 'Reference: the\nsilences', 'Reference: of', 'Reference: his', 'Reference: soul.\n\n*****\n\nBut', 'Reference: as', 'Reference: he', 'Reference: descended', 'Reference: the', 'Reference: hill,', 'Reference: a', 'Reference: sadness\ncame', 'Reference: upon', 'Reference: him,', 'Reference: and', 'Reference: he', 'Reference: thought', 'Reference: in', 'Reference: his\nheart:\n\nHow', 'Reference: shall', 'Reference: I', 'Reference: go', 'Reference: in', 'Reference: peace', 'Reference: and', 'Reference: without\nsorrow?', 'Reference: Nay,', 'Reference: not', 'Reference: without', 'Reference: a', 'Reference: wound', 'Reference: in', 'Reference: the\nspirit', 'Reference: shall', 'Reference: I', 'Reference: leave', 'Reference: this', 'Reference: city.', 'Reference: {8}Long\nwere', 'Reference: the', 'Reference: days', 'Reference: of', 'Reference: pain', 'Reference: I', 'Reference: have', 'Reference: spent\nwithin', 'Reference: its', 'Reference: walls,', 'Reference: and', 'Reference: long', 'Reference: were', 'Reference: the\nnights', 'Reference: of', 'Reference: aloneness;', 'Reference: and', 'Reference: who', 'Reference: can', 'Reference: depart\nfrom', 'Reference: his', 'Reference: pain', 'Reference: and', 'Reference: his', 'Reference: aloneness', 'Reference: without\nregret?\n\nToo', 'Reference: many', 'Reference: fragments', 'Reference: of', 'Reference: the', 'Reference: spirit', 'Reference: have', 'Reference: I\nscattered', 'Reference: in', 'Reference: these', 'Reference: streets,', 'Reference: and', 'Reference: too', 'Reference: many\nare', 'Reference: the', 'Reference: children', 'Reference: of', 'Reference: my', 'Reference: longing', 'Reference: that', 'Reference: walk\nnaked', 'Reference: among', 'Reference: these', 'Reference: hills,', 'Reference: and', 'Reference: I', 'Reference: cannot\nwithdraw', 'Reference: from', 'Reference: them', 'Reference: without', 'Reference: a', 'Reference: burden', 'Reference: and\nan', 'Reference: ache.\n\nIt', 'Reference: is', 'Reference: not', 'Reference: a', 'Reference: garment', 'Reference: I', 'Reference: cast', 'Reference: off', 'Reference: this\nday,', 'Reference: but', 'Reference: a', 'Reference: skin', 'Reference: that', 'Reference: I', 'Reference: tear', 'Reference: wit ...

# %% [markdown]
# Another thing you may have noticed is that some words contain a line break. Let's write a function to split those words. Our function will return the string split on the character `\n`. Write your function in the cell below.

# %%
def line_break(x):
    return x.split('\n')
    # your code here

# %% [markdown]
# Apply the `line_break` function to the `prophet_reference` list. Name the new list `prophet_line`.

# %%
# your code here

prophet_line = [line for reference in prophet_reference for line in line_break(reference)]

# %% [markdown]
# If you look at the elements of `prophet_line`, you will see that the function returned lists and not strings. Our list is now a list of lists. Flatten the list using list comprehension. Assign this new list to `prophet_flat`.

# %%
prophet_flat = [i for sub in prophet_line for i in sub]

# %%
# your code here
prophet_flat = [i for sub in prophet_line for i in sub]

# %% [markdown]
# # Challenge 2 - Filtering
#
# When printing out a few words from the book, we see that there are words that we may not want to keep if we choose to analyze the corpus of text. Below is a list of words that we would like to get rid of. Create a function that will return false if it contains a word from the list of words specified and true otherwise.

# %%
def word_filter(x):
    if x in word_list:
       return False  # The word is in the list, return False
    else:
       return True
    # your code here
word_list = ['and', 'the', 'a', 'an']
print(word_filter('and'))
print(word_filter('John'))
# Out:
# False
# True

# %% [markdown]
# Use the `filter()` function to filter out the words speficied in the `word_filter()` function. Store the filtered list in the variable `prophet_filter`.

# %%
# your code here
def word_filter(x): 
    word_list = ['and', 'the', 'a', 'an']  
    return x not in word_list  

prophet_filter = list(filter(word_filter, word_list))
print(prophet_filter)
# Out:
# []

# %% [markdown]
# # Bonus Challenge
#
# Rewrite the `word_filter` function above to not be case sensitive.

# %%
def word_filter_case(x):
   
    word_list = ['and', 'the', 'a', 'an']
    
    # your code here
    return x.lower() not in (word.lower() for word in word_list)

# %% [markdown]
# # Challenge 3 - Reducing
#
# #### Now that we have significantly cleaned up our text corpus, let's use the `reduce()` function to put the words back together into one long string separated by spaces.
#
# We will start by writing a function that takes two strings and concatenates them together with a space between the two strings.

# %%
def concat_space(a, b):
    '''
    Input:Two strings
    Output: A single string separated by a space
        
    Example:
    Input: 'John', 'Smith'
    Output: 'John Smith'
    '''
    
    # your code here
    return a + ' ' + b

# %%
# your code here
from functools import reduce

word_list = ['and', 'the', 'a', 'an']
result = reduce(concat_space, word_list)
print(result)
# Out:
# and the a an

# %% [markdown]
# Use the function above to reduce the text corpus in the list `prophet_filter` into a single string. Assign this new string to the variable `prophet_string`.

# %%
# your code here
from functools import reduce
prophet_filter = [
    "Your", "children", "are", "not", "your", "children.",
    "They", "are", "sons", "daughters", "of", "Life's", "longing", "for", "itself."]

prophet_string = reduce(concat_space, prophet_filter)
print(prophet_string)
# Out:
# Your children are not your children. They are sons daughters of Life's longing for itself.
